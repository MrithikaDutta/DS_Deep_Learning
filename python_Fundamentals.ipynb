# %% [markdown]
# <a href="https://colab.research.google.com/github/MrithikaDutta/DS_Deep_Learning/blob/main/python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HELLO!I am Mrithika")
print("University: Daffodil International University")
print("Department: Software Engineering")
print("Major: Data Science")
# Out:
# HELLO!I am Mrithika
# University: Daffodil International University
# Department: Software Engineering
# Major: Data Science
