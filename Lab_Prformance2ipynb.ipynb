# %% [markdown]
# <a href="https://colab.research.google.com/github/MrithikaDutta/DS_Deep_Learning/blob/main/Lab_Prformance2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
image_1 = cv2.imread('/content/drive/MyDrive/panda.jpg', cv2.IMREAD_GRAYSCALE)
unique_gray_levels = np.unique(image_1)
print(f"The number of unique gray levels in the image is: {len(unique_gray_levels)}")
# Out:
# The number of unique gray levels in the image is: 256

# %%
len(unique_gray_levels)
# Out:
# 256

# %% [markdown]
# ## plot histogram of image

# %%
plt.subplot(1,2,1)
plt.imshow(image_1,cmap='gray')
plt.title('image')
plt.subplot(1,2,2)
hist,bins=np.histogram(image_1.ravel(),253,[0,256])
plt.plot(hist)
plt.title('histogram')
plt.grid(True)
plt.show()

# %%
hist, bins = np.histogram(image_1.ravel(), 256, [0, 256])
cumulative_hist = np.cumsum(hist)
plt.plot(cumulative_hist)
plt.xlabel('Gray Level')
plt.ylabel('Cumulative Frequency')
plt.title('Cumulative Histogram')
plt.grid(True)
plt.show()

# %% [markdown]
# # **Shifting**

# %%
image_1_shifted = np.clip(image_1 + 100, 0, 255).astype(np.uint8)

# %%
plt.imshow(image_1_shifted,cmap='gray')
plt.axis(False)
# Out:
# (np.float64(-0.5), np.float64(629.5), np.float64(421.5), np.float64(-0.5))

# %%
unique_gray_levels_shifted = np.unique(image_1)

print(f"The number of unique gray levels in the image is: {len(unique_gray_levels_shifted)}")
# Out:
# The number of unique gray levels in the image is: 256

# %%
plt.subplot(1,2,1)
plt.imshow(image_1_shifted,cmap='gray')
plt.title('image')
plt.subplot(1,2,2)
hist,bins=np.histogram(image_1_shifted.ravel(),255,[0,256])
plt.plot(hist)
plt.title('histogram')
plt.grid(True)
plt.show()

# %%
hist, bins = np.histogram(image_1_shifted.ravel(), 256, [0, 256])
cumulative_hist = np.cumsum(hist)
plt.plot(cumulative_hist)
plt.xlabel('Gray Level')
plt.ylabel('Cumulative Frequency')
plt.title('Cumulative Histogram')
plt.grid(True)
plt.show()

# %% [markdown]
# # Equalization

# %%
equ = cv2.equalizeHist(image_1)
plt.imshow(equ,cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(629.5), np.float64(421.5), np.float64(-0.5))

# %%
plt.subplot(1,2,1)
plt.imshow(equ,cmap='gray')
plt.title('image')
plt.axis('off')
plt.subplot(1,2,2)
hist,bins=np.histogram(equ.ravel(),253,[0,256])
plt.plot(hist)
plt.title('histogram')
plt.grid(True)
plt.show()

# %%
hist, bins = np.histogram(equ.ravel(), 256, [0, 256])
cumulative_hist = np.cumsum(hist)
plt.plot(cumulative_hist)
plt.xlabel('Gray Level')
plt.ylabel('Cumulative Frequency')
plt.title('Cumulative Histogram')
plt.grid(True)
plt.show()

# %% [markdown]
# # Equalization for shifted image

# %%
equ_shifted = cv2.equalizeHist(image_1_shifted)
plt.imshow(equ,cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(629.5), np.float64(421.5), np.float64(-0.5))

# %%
plt.subplot(1,2,1)
plt.imshow(equ_shifted,cmap='gray')
plt.title('image')
plt.axis('off')
plt.subplot(1,2,2)
hist,bins=np.histogram(equ_shifted.ravel(),253,[0,256])
plt.plot(hist)
plt.title('histogram')
plt.grid(True)
plt.show()

# %%
hist, bins = np.histogram(equ_shifted.ravel(), 256, [0, 256])
cumulative_hist = np.cumsum(hist)
plt.plot(cumulative_hist)
plt.xlabel('Gray Level')
plt.ylabel('Cumulative Frequency')
plt.title('Cumulative Histogram')
plt.grid(True)
plt.show()

# %% [markdown]
# # **contrast stretching**

# %%
try_low_level_range_images=cv2.imread('/content/drive/MyDrive/Fogg.jpg',0)

# %%
if try_low_level_range_images is not None:
    plt.subplot(1,2,1)
    plt.imshow(try_low_level_range_images,cmap='gray')
    plt.title('image')
    plt.subplot(1,2,2)
    hist,bins=np.histogram(try_low_level_range_images.ravel(),216)
    plt.plot(hist)
    plt.title('histogram')
    plt.grid(True)
    plt.show()
else:
    print("Error: The image 'Fogg.png' could not be loaded. Please check the file path and ensure the image exists.")
#from 50 to 80 nearly equal

# %%
# min_value = np.min(try_low_level_range_images)
# max_value = np.max(try_low_level_range_images)
# image_new = (try_low_level_range_images - min_value) * (255 / (max_value - min_value))
image_new=(try_low_level_range_images-np.min(try_low_level_range_images))*((255-0)/(np.max(try_low_level_range_images)-np.min(try_low_level_range_images)))
cv2_imshow(image_new)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
cv2_imshow(try_low_level_range_images)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
try_low_level_range_images.min()
# Out:
# np.uint8(0)

# %%
image_new.min()
# Out:
# np.float64(0.0)

# %%
try_low_level_range_images.max(),image_new.max()
# Out:
# (np.uint8(253), np.float64(255.0))
